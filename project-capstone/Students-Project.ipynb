# %% [markdown]
# **Breno Amaral Santos - C02177**
# *Sua tarefa é realizar análise e visualização de dados usando bibliotecas Python.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Students-Project.csv')

# %%
df
# Out:
#           id first_name last_name date_of_birth               ethnicity  \
# 0   111111.0       John       Doe       01/2000                Hispanic
# 1   111112.0       Jane     Smith       05/2001                Hispanic
# 2   111113.0      Sarah    Thomas       21/2002                Hispanic
# 3   111114.0      Frank     Brown       13/2002  Race/ethnicity unknown
# 4   111115.0       Mike     Davis       31/2001                   White
# 5   111116.0   Jennifer    Wilson       01/2002                   Asian
# 6   111117.0    Jessica    Garcia       01/2000                   White
# 7   111118.0       Fred     Clark       17/1999                Hispanic
# 8   111119.0        Bob     Lopez       04/1998                   White
# 9        NaN        NaN       NaN           NaN                     NaN
# 10       NaN        NaN       NaN           NaN                     NaN
# 11       NaN        NaN       NaN           NaN                     NaN
# ...

# %%
df.head()
# Out:
#          id first_name last_name date_of_birth               ethnicity gender  \
# 0  111111.0       John       Doe       01/2000                Hispanic      M
# 1  111112.0       Jane     Smith       05/2001                Hispanic      F
# 2  111113.0      Sarah    Thomas       21/2002                Hispanic      M
# 3  111114.0      Frank     Brown       13/2002  Race/ethnicity unknown      M
# 4  111115.0       Mike     Davis       31/2001                   White      F
#
#      status entry_academic_period  exclusion_type  act_composite  ...  \
# 0        FT             Fall 2008             NaN            NaN  ...
# 1  TRANSFER             Fall 2006             NaN            NaN  ...
# 2      FTFT             Fall 2006             NaN           14.0  ...
# 3      FTFT             Fall 2006             NaN            NaN  ...
# 4      FTFT             Fall 2007             NaN           22.0  ...
#
# ...

# %%
df.dropna(subset=['id'], inplace=True)
df
# Out:
#          id first_name last_name date_of_birth               ethnicity gender  \
# 0  111111.0       John       Doe       01/2000                Hispanic      M
# 1  111112.0       Jane     Smith       05/2001                Hispanic      F
# 2  111113.0      Sarah    Thomas       21/2002                Hispanic      M
# 3  111114.0      Frank     Brown       13/2002  Race/ethnicity unknown      M
# 4  111115.0       Mike     Davis       31/2001                   White      F
# 5  111116.0   Jennifer    Wilson       01/2002                   Asian      M
# 6  111117.0    Jessica    Garcia       01/2000                   White      F
# 7  111118.0       Fred     Clark       17/1999                Hispanic      F
# 8  111119.0        Bob     Lopez       04/1998                   White      F
#
#      status entry_academic_period  exclusion_type  act_composite  ...  \
# 0        FT             Fall 2008             NaN            NaN  ...
# ...

# %%
coluna = df['entry_age']
media = coluna.mean()
parseInt = int(media)
print(f"A média de idade dos alunos é {parseInt} anos")
# Out:
# A média de idade dos alunos é 18 anos

# %%
age['first_name'] = pd.factorize(age['first_name'])[0]
sns.lmplot(x='entry_age', y='first_name', data=age, aspect=2, height=6)

# %%
sns.countplot(x='entry_age', data=df, palette='Set3')
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_11568\502134333.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='entry_age', data=df, palette='Set3')
# <Axes: xlabel='entry_age', ylabel='count'>
